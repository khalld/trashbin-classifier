# %% [markdown]
# # Introduzione

# %% [markdown]
# Carico il dataset creato da `create_dataset.py` da google drive
#
# >
# L'obbiettivo del progetto è quello di implementare un classificatore che sia in grado di distinguere quando un secchio è pieno, a metà, vuoto. Abbiamo registrato dei video per tre secchi diversi, dove abbiamo ripreso se i secchi fossero vuoti, pieni o a metà. I video sono stati registrati a 30fps in alta risoluzione. (iPhone XS e Huawei P20)
#
# Abbiamo estratto per video 100 frame utilizzando il codice presente sul file `create_dataset.py`
#
# Sono state associate per ogni immagine delle classi numeriche rispettivamente:
# - -1: empty
# - 0: half
# - 1: full
#
# Le label sono state inserite nel file `all_labels.txt` rispettivamente nell'ordine
# `'nome-immagine': 'classe-appartenza'`
#
# ###### Il file all labels è stato letto da una funzione implementate in create dataset dove viene effettuata una permutazione randomica su tutte le 900 labels e sono state suddivise tra train e test (650 per training 250 test)
#
# **i file .txt li ho importati brutalmente spiegare poi meglio il rpocedimento**

# %%
## mount google drive
from google.colab import drive
import zipfile

drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !unzip /content/gdrive/MyDrive/img.zip -d /content/gdrive/MyDrive/dataset/
# Out:
# Archive:  /content/gdrive/MyDrive/img.zip
#    creating: /content/gdrive/MyDrive/dataset/img/
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_143.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_625.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_631.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_157.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_619.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_180.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_194.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_802.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_816.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_427.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_341.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_355.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_433.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_87.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_369.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_93.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_78.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_382.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_396.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_44.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_50.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_553.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_235.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_221.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_547.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_209.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_590.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_584.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_751.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_745.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_779.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_792.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_786.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_787.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_793.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_778.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_744.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_750.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_585.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_591.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_208.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_220.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_546.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_552.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_234.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_51.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_45.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_397.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_79.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_383.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_368.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_92.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_86.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_354.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_432.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_426.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_340.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_817.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_803.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_195.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_181.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_618.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_630.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_156.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_142.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_624.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_154.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_632.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_626.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_140.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_168.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_197.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_829.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_183.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_815.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_801.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_430.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_356.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_342.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_424.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_90.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_84.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_418.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_395.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_381.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_53.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_47.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_544.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_222.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_236.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_550.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_578.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_587.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_593.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_746.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_752.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_785.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_791.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_790.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_784.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_753.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_747.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_592.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_586.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_579.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_237.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_551.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_545.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_223.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_46.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_52.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_380.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_394.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_419.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_85.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_91.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_343.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_425.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_431.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_357.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_800.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_814.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_182.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_196.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_828.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_169.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_627.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_141.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_155.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_633.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_179.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_637.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_151.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_145.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_623.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_810.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_804.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_192.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_186.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_838.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_95.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_409.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_81.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_353.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_435.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_421.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_347.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_56.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_42.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_390.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_384.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_569.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_227.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_541.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_555.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_233.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_582.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_596.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/.DS_Store
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_743.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_757.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_780.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_794.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_795.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_781.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_756.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_742.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_597.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_583.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_554.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_232.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_226.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_540.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_568.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_385.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_391.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_43.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_57.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_420.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_346.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_352.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_434.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_80.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_408.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_94.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_187.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_839.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_193.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_805.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_811.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_144.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_622.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_636.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_150.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_178.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_608.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_620.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_146.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_152.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_634.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_807.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_813.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_185.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_191.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_378.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_82.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_96.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_344.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_422.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_436.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_350.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_41.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_55.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_387.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_69.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_393.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_218.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_230.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_556.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_542.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_224.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_595.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_581.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_768.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_754.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_740.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_797.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_783.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_782.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_796.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_741.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_755.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_769.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_580.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_594.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_543.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_225.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_231.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_557.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_219.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_68.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_392.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_386.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_54.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_40.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_437.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_351.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_345.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_423.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_97.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_379.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_83.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_190.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_184.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_812.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_806.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_153.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_635.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_621.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_147.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_609.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_646.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_120.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_134.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_652.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_108.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_685.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_849.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_691.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_861.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_875.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_322.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_444.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_450.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_336.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_478.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_487.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_493.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_27.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_33.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_256.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_530.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_524.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_242.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_518.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_295.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_281.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_732.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_726.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_3.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_2.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_727.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_733.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_280.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_294.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_519.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_525.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_243.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_257.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_531.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_32.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_26.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_492.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_486.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_479.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_451.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_337.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_323.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_445.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_874.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_860.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_690.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_848.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_684.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_109.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_135.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_653.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_647.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_121.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_651.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_889.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_137.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_123.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_645.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_679.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_692.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_686.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_876.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_862.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_335.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_453.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_447.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_321.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_309.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_490.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_18.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_484.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_30.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_24.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_241.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_527.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_533.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_255.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_269.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_282.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_296.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_725.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_731.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_719.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_0.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_1.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_718.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_730.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_724.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_297.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_283.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_268.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_532.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_254.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_240.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_526.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_25.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_31.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_485.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_19.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_491.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_308.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_446.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_320.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_334.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_452.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_863.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_877.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_687.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_693.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_678.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_122.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_644.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_888.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_650.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_136.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_668.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_132.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_654.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_640.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_898.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_126.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_873.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_867.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_697.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_683.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_318.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_456.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_330.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_324.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_442.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_35.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_21.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_495.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_481.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_278.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_522.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_244.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_250.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_536.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_287.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_293.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_708.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_720.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_734.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_5.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_4.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_735.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_721.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_709.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_292.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_286.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_251.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_537.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_523.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_245.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_279.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_480.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_494.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_20.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_34.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_325.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_443.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_457.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_331.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_319.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_682.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_696.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_866.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_872.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_899.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_641.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_127.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_133.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_655.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_669.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_119.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_125.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_643.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_657.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_131.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_864.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_870.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_858.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_680.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_694.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_469.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_441.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_327.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_333.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_455.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_22.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_36.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_482.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_496.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_509.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_535.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_253.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_247.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_521.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_290.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_284.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_737.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_723.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_6.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_7.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_722.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_736.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_285.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_291.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_246.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_520.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_534.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_252.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_508.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_497.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_483.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_37.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_23.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_332.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_454.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_440.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_326.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_468.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_695.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_681.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_859.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_871.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_865.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_656.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_130.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_124.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_642.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_118.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_667.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_101.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_115.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_673.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_883.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_129.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_897.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_868.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_840.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_698.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_854.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_303.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_465.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_471.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_317.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_459.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_12.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_277.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_511.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_505.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_263.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_539.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_288.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_713.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_707.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_706.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_712.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_289.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_538.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_504.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_262.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_276.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_510.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_13.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_458.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_470.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_316.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_302.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_464.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_855.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_699.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_841.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_869.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_128.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_896.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_882.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_114.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_672.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_666.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_100.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_670.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_116.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_102.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_664.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_894.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_658.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_880.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_857.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_843.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_314.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_472.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_466.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_300.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_328.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_39.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_11.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_499.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_260.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_506.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_512.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_274.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_248.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_704.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_710.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_738.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_9.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_8.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_739.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_711.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_705.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_249.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_513.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_275.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_261.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_507.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_498.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_10.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_38.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_329.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_467.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_301.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_315.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_473.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_842.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_856.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_881.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_659.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_895.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_103.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_665.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_671.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_117.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_649.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_891.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_885.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_113.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_675.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_661.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_107.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_852.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_846.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_339.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_477.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_311.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_305.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_463.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_488.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_14.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_28.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_259.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_503.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_265.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_271.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_517.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_729.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_701.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_715.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_714.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_700.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_728.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_270.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_516.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_502.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_264.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_258.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_29.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_15.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_489.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_304.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_462.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_476.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_310.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_338.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_847.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_853.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_660.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_106.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_112.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_674.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_884.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_890.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_648.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_138.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_886.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_892.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_104.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_662.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_676.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_110.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_845.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_851.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_689.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_879.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_448.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_460.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_306.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_312.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_474.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_17.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_528.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_514.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_272.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_266.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_500.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_299.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_716.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_702.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_703.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_717.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_298.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_267.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_501.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_515.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_273.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_529.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_16.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_313.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_475.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_461.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_307.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_449.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_878.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_688.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_850.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_844.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_677.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_111.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_105.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_663.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_893.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_139.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_887.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_162.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_604.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_610.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_176.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_638.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_823.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_837.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_189.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_406.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_360.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_374.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_412.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_348.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_59.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_65.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_71.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_572.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_214.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_200.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_566.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_228.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_599.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_770.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_764.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_758.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_759.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_765.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_771.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_598.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_229.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_201.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_567.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_573.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_215.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_70.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_64.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_58.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_349.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_375.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_413.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_407.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_361.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_836.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_188.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_822.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_639.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_611.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_177.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_163.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_605.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_175.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_613.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_607.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_161.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_149.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_808.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_834.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_820.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_411.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_377.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_363.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_405.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_99.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_439.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_72.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_388.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_66.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_565.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_203.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_217.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_571.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_559.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_767.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_773.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_798.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_799.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_772.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_766.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_558.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_216.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_570.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_564.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_202.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_67.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_73.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_389.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_438.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_362.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_98.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_404.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_410.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_376.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_821.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_835.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_809.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_148.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_606.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_160.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_174.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_612.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_158.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_616.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_170.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_164.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_602.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_831.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_825.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_819.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_428.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_372.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_414.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_88.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_400.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_366.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_77.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_63.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_399.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_548.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_206.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_560.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_574.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_212.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_762.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_776.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_789.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_788.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_777.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_763.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_575.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_213.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_207.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_561.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_549.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_62.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_398.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_76.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_401.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_367.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_373.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_89.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_415.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_429.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_818.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_824.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_830.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_165.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_603.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_617.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_171.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_159.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_629.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_601.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_167.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_173.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_615.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_826.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_198.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_832.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_359.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_365.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_403.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_417.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_371.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_60.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_74.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_48.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_239.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_211.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_577.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_563.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_205.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_588.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_749.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_775.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_761.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_760.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_774.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_748.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_589.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_562.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_204.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_210.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_576.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_238.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_49.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_75.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_61.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_416.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_370.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_364.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_402.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_358.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_833.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_827.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_199.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_172.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_614.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_600.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_166.jpg
#   inflating: /content/gdrive/MyDrive/dataset/img/trashbean_628.jpg

# %%
import torch
from torch.utils.data.dataset import Dataset
from torch.utils.data import DataLoader
from PIL import Image
from os import path
from torchvision import transforms
import numpy as np
from sklearn.model_selection import train_test_split
import cv2
from tqdm import tqdm


from matplotlib import pyplot as plt
import matplotlib.image as mpimg
import random

# %% [markdown]
# # Construction of dataset
#
# - `all_labels.txt`: All image's labels of all entire dataset
# - `classes.txt`: classes
# - `test.txt`: test dataset
# - `test.txt`: train dataset

# %%
class TrashbeanDataset(Dataset):
    def __init__(self, base_path, txt_list, transform=None):
        self.base_path = base_path
        self.images = np.loadtxt(txt_list, dtype=str, delimiter=',')
        self.transform = transform

    def __getitem__(self, index):
        f,c = self.images[index] # recuperiamo il path dell'immagine di indice index e la relativa etichetta
        im = Image.open(self.base_path + f)   ## load img with PIL
        
        if self.transform is not None:          ## toTensor, resize, normalize etc...
            im = self.transform(im)

        label = int(c) # converto l'etichetta in intero

        return (im, label)  # usare una tupla sembra l'opzione migliore in termini di velocità e memoria 

    def __len__(self): # restituisce numero di campioni: la lunghezza della lista images
        return len(self.images)

# %% [markdown]
# Carichiamo il dataset in esempio per visualizzare che la classe funzioni correttamente

# %%
dic = {
    -1: "empty",
    0: "half",
    1: "full"
}

path = 'gdrive/MyDrive/dataset/'

transform = transforms.Compose([
                                transforms.Resize(100), # per ridurre i costi computazionali ridimensioniamo l'immagine
                                transforms.ToTensor()
])

dataset = TrashbeanDataset(path + 'img/', path + 'labels/all_labels_rand.txt', transform=transform)

# visualizziamo il primo elemento con __geitem e controlliamo che il tipo assegnato sia corretto

print(dataset.__len__())

print(dataset[0][0].size())
# Out:
# 900
# torch.Size([3, 177, 100])

# %%
plt.figure(figsize=(15,10))
for i in range(10):
    plt.subplot(2,5,i+1)
    plt.imshow(np.asarray(dataset[i][0].permute(1, 2, 0)), aspect="auto")
    plt.xlabel(dic[dataset[i][1]])
plt.show()

# %% [markdown]
# ## Adesso è necessario calcolare media e varianza
#
# Dobbiamo calcolare media e varianza per ogni immagine del dataset intero per ogni canale
#
# (media_r, media_g, media_b)
# (dvstd_r, devst_g, devst_b)

# %%
dataset_loader = DataLoader(dataset=dataset, shuffle=False, batch_size=150)  # non serve shuffle perché già randomico

# %%
dataset[0][0].shape
# Out:
# torch.Size([3, 177, 100])

# %% [markdown]
# Calcoliamo:
# 1.   media
# 2.   dev std

# %%
def mean_std(loader):
  channels_sum, channels_squared_sum, num_batches = 0, 0, 0

  for data, _ in loader:
    channels_sum += torch.mean(data, dim=[0,2,3])
    channels_squared_sum += torch.mean(data**2, dim=[0,2,3])
    num_batches += 1
  
  mean = channels_sum/num_batches
  std = (channels_squared_sum/num_batches - mean**2)**0.5

  return mean, std

# %%
mean_std(dataset_loader)
# Out:
# (tensor([0.5106, 0.4575, 0.4110]), tensor([0.2254, 0.2106, 0.2229]))

# %% [markdown]
# La media e la deviazione standard dell'intero dataset non ridimensionato è:
#
# - media sarà: **[0.5106, 0.4575, 0.4110]**
# - deviazione standard sarà: **[0.2321, 0.2178, 0.2296]**
#
# Abbiamo notato durante l'implementazione del progetto che le immagini andavano scalate per via del carico computazione per processare il training. Dunque abbiamo ricalcolato i valori dopo averli scalati e abbiamo notato una differenza solo nella deviazione standard
#
# - **0.2254, 0.2106, 0.2229**

# %% [markdown]
# # Implementazione rete e classificatori
# (controlla che classificatori sia corretto)
# - AverageValue meter
# - train classifier
# - la rete

# %% [markdown]
# Creiamo la classe average value meter **scrivere a cosa serve**

# %%
class AverageValueMeter():
  def __init__(self):
    self.reset()

  def reset(self):
    self.sum = 0
    self.num = 0
  
  def add(self, value, num):
    self.sum += value*num
    self.num += num
  
  def value(self):
    try:
      return self.sum/self.num
    except:
      return None

# %% [markdown]
# Implementiamo il test classifier (discesa serve ??)

# %%
def train_classifier(model, train_loader, test_loader, exp_name='experiment', lr=0.01, epochs=10, momentum=0.99, logdir='logs'):
    criterion = nn.CrossEntropyLoss()
    optimizer = SGD(model.parameters(), lr, momentum=momentum)

    # meters
    loss_meter = AverageValueMeter()
    acc_meter = AverageValueMeter()
    # writer
    writer = SummaryWriter(join(logdir, exp_name))
    # device
    device = "cuda" if torch.cuda.is_available() else "cpu"
    model.to(device)
    ## definiamo un dizionario contenente i loader di training e test
    loader = {
        'train': train_loader,
        'test': test_loader
    }
    global_step = 0
    for e in range(epochs):
        # iteriamo tra due modalità: train e test
        for mode in ['train', 'test']:
            loss_meter.reset(); acc_meter.reset()
            model.train() if mode == 'train' else model.eval()
            with torch.set_grad_enabled(mode=='train'): # abilitiamo i gradienti o solo in training
                for i, batch in enumerate(loader[mode]):
                    x=batch[0].to(device) # portiamoli su device corretto
                    y=batch[1].to(device)
                    output = model(x)

                    # aggiorniamo il global_step
                    # conterrà il numero di campioni visti durante il training
                    n = x.shape[0]  # n di elementi nel batch
                    global_step += n
                    l = criterion(output, y)

                    if mode=='train':
                        l.backward()
                        optimizer.step()
                        optimizer.zero_grad()

                    acc = accuracy_score(y.to('cpu'), output.to('cpu').max(1)[1])
                    loss_meter.add(l.item(), n)
                    acc_meter.add(acc,n)

                    # loggiamo i risultati iterazione per iterazione solo durante il training
                    if mode == 'train':
                        writer.add_scalar('loss/train', loss_meter.value(), global_step=global_step)
                        writer.add_scalar('accuracy/train', acc_meter.value(), global_step=global_step)

                        # una volta finita l'epoca sia nel caso di training che di test loggiamo le stime finali

                writer.add_scalar('loss/' + mode, loss_meter.value(), global_step=global_step)
                writer.add_scalar('accuracy/' + mode, acc_meter.value(), global_step=global_step)

                        ## conserviamo i pesi del modello alla fine di un ciclo di training e test

        torch.save(model.state_dict(), '%s-%d.pth'%(exp_name, e+1))
    return model

# %%
def test_classifier(model, loader):
  device = "cuda" if torch.cuda.is_available() else "cpu"
  model.to(device)
  predictions, labels = [], []
  for batch in loader:
    x = batch[0].to(device)
    y = batch[1].to(device)
    output = model(x)
    preds = output.to('cpu').max(1)[1].numpy()
    labs = y.to('cpu').numpy()
    predictions.extend(list(preds))
    labels.extend(list(labs))
  return np.array(predictions), np.array(labels)

# %% [markdown]
# # Rete

# %% [markdown]
# Importiamo il dataset di train e test da calcolare

# %%
transform = transforms.Compose([ transforms.ToTensor(),
                                 transforms.Resize(100), # 177 x 100
                                 transforms.Normalize( ( 0.5106, 0.4575, 0.4110) , (0.2254, 0.2106, 0.2229) ),
                                 torch.flatten # 1080*1920*3 = 6220800 || dataset normalizzato: 100*177*3 = 53100
                               ])

# import dataset train & test
dataset_training = TrashbeanDataset(path + 'img/', path + 'labels/train.txt', transform=transform)
dataset_test = TrashbeanDataset(path + 'img/', path + 'labels/test.txt', transform=transform)

# %%
dataset_training.__len__()
# Out:
# 650

# %%
dataset_test.__len__()
# Out:
# 250

# %%
dataset_training_loader = DataLoader(dataset_training, batch_size=50, num_workers=2, shuffle=True)
dataset_test_loader =     DataLoader(dataset_test, batch_size=50, num_workers=2)

# %% [markdown]
# Nota:
# Inizialmente stavamo computando i batch per senza aver fatto il resize dell'immagine.
# L'operazione sottostante inizialmente ha impiegato circa più di un minuto, mentre dopo aver applicato il resize ha impiegato 25s

# %%
for batch in dataset_training_loader:
  pass

print(batch[0].shape)
# Out:
# torch.Size([50, 53100])

# %% [markdown]
# Per semplicità implementiamo la Lenet color per effettuare i primi test

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Input 177 x 100

# %%
from torch import nn
class LeNetColor(nn.Module):
  def __init__(self):
    super(LeNetColor, self).__init__()
    #ridefiniamo il modello utilizzando i moduli sequential.
    #ne definiamo due: un "feature extractor", che estrae le feature maps #e un "classificatore" che implementa i livelly FC
    self.feature_extractor = nn.Sequential(
      nn.Conv2d(3, 18, 5), #Input: 3 x 32 x 32. Ouput: 18 x 28 x 28
      nn.MaxPool2d(2), #Input: 18 x 28 x 28. Output: 18 x 14 x 14
      nn.ReLU(),
      nn.Conv2d(18, 28, 5), #Input 18 x 14 x 14. Output: 28 x 10 x 10
      nn.MaxPool2d(2), #Input 28 x 10 x 10. Output: 28 x 5 x 5
      nn.ReLU()
    )

    self.classifier = nn.Sequential(
        nn.Linear(700, 360), # Input 28 * 5 * 5
        nn.ReLU(),
        nn.Linear(360, 252),
        nn.ReLU(),
        nn.Linear(252, 100)
    )

  def forward(self,x):
    #applichiamo tutte le diverse trasformazioni in cascata
    x = self.feature_extractor(x)
    x = self.classifier(x.view(x.shape[0],-1))
    return x

# %%
# %load_ext tensorboard
# %tensorboard --logdir logs

# %% [markdown]
# Dobbiamo
# - Il tipo di modello (??)
# - test classifier
# - train classifier
# - caricare dataset test e training con dataLoader (normalizzati)
# - procedura di addestramento
# - tensorboard
